# %% [raw]
# ---
# title: "Other useful concepts"
# format:
#   revealjs:
#     scrollable: true
# ---

# %% [markdown]
# ## Further reading
#
# ### Guardrails
# - [Guardrails - LangChain](https://docs.langchain.com/oss/python/langchain/guardrails)
# - [Guardrails - DeepLearning.AI course](https://www.deeplearning.ai/short-courses/safe-and-reliable-ai-via-guardrails/)
# - [Essential Guide to LLM Guardrails: Llama Guard, NeMo - Medium post](llm_guardrails.pdf)
# - [How to implement LLM guardrails - OpenAI cookbook](https://cookbook.openai.com/examples/how_to_use_guardrails)
#
# ### Context engineering
# - [Context engineering - LangChain](https://docs.langchain.com/oss/python/langchain/context-engineering)
# - [Context Rot: When Long Context Fails](https://www.youtube.com/watch?v=3s_N60u0jEY)
# - [Continual In-Context Learning](https://blog.langchain.dev/dosu-langsmith-no-prompt-eng/)
#
# ### MCP
# - [Model Context Protocol (MCP) - LangChai](https://docs.langchain.com/oss/python/langchain/mcp)
#
# ### MultiAgent
# - [Multi-Agent - LangChain](https://docs.langchain.com/oss/python/langchain/multi-agent/index)
#
# ### Prompt caching & prompt engineering
# - [prompt caching](https://platform.openai.com/docs/guides/prompt-caching)
# - [Prompt Engineering - Parlance Education](https://parlance-labs.com/education/prompt_eng/berryman.html)
# - [Prompt Engineering - DeepLearning.AI course](https://www.deeplearning.ai/short-courses/chatgpt-prompt-engineering-for-developers/)
# - [Building resilient prompts using an evaluation flywheel - OpenAI cookbook](https://cookbook.openai.com/examples/evaluation/building_resilient_prompts_using_an_evaluation_flywheel)
# - [Prompt baking](https://medium.com/@linz07m/prompt-baking-making-prompts-permanent-in-language-models-662a96092e90)
#
# ### Fact-checker
# - [Build your own content fact-checker with OpenAI gpt-oss-120B, Cerebras, and Parallel - OpenAI cookbook](https://github.com/openai/openai-cookbook/blob/main/articles/gpt-oss/build-your-own-fact-checker-cerebras.ipynb)
#
# ### Interpretability
# - [Interpretability](https://www.youtube.com/watch?v=lg1-M8hEX50)

# %% [markdown]
# ## Full courses
#
# - [LLM Course - Maxime Labonne](https://github.com/mlabonne/llm-course)
#
# ## Other material
#
# - [OpenAI cookbooks](https://cookbook.openai.com/)

# %% [markdown]
# ## Investigate
#
# - RLHF
# - Automatic Prompt refinement
# - Dynamic Selection of Examples (for few-shot learning, in prompt)
#     - [LangChain](https://docs.langchain.com/langsmith/index-datasets-for-dynamic-few-shot-example-selection)
