# %% [raw]
# ---
# title: "Error Analysis"
# author: "Jaume Amores"
# format:
#   revealjs:
#     scrollable: true
# ---

# %% [markdown]
# # Links
#
# - [Carrying Out Error Analysis (C3W2L01) | DeepLearning.AI](https://youtu.be/JoAxZsdw_3w)
# - [Q: Why is "error analysis" so important in LLM evals, and how is it performed? | Hamel Husain's FAQ](https://hamel.dev/blog/posts/evals-faq/#q-why-is-error-analysis-so-important-in-llm-evals-and-how-is-it-performed)
# - [Intro To Error Analysis: Creating Custom Data Annotation Apps (4k version) | Hamel Husain](https://youtu.be/qH1dZ8JLLdU)
# - [10 Ways to Be Data Illiterate (and How to Avoid Them) | Jason Liu](https://jxnl.co/writing/2024/06/02/10-ways-to-be-data-illiterate-and-how-to-avoid-them/)
